# %%
# Loading the dataset

# mount your drive to be access your files.
# from google.colab import drive
# drive.mount('/content/drive')

# Commenting this out since I run the Jupyter notebook locally
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Part 1
#
# For this part we will use the ``Customer_Churn`` data, and do some exploratory data analysis.

# %%
churn = pd.read_csv("data/Customer_Churn.csv")

# %%
churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# ## Question 1
#
# Create a horizontal barplot that will show the number of customers per country in descending order. The bars should be green and thin.

# %%
#answer here
#  Create a barplot for the number of customers per country in descending order.
plt.figure(figsize=(10, 5))
plt.bar(churn.Geography.value_counts().index, churn.Geography.value_counts().values, color='#0f0', width=0.5)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Question 2
#
# Generate the following DataFrame, where the values represent the ratio of males and females in each country:
#
# ![DataFrame1](https://drive.google.com/uc?id=1v89MZPlHm_7FGbaTKyEgR1da8YJlgFxb)
#
# The create the following bar plot comparing the ratios of males to females in each country:
#
# ![BarPlot1](https://drive.google.com/uc?id=1iC3EH9iLlYhU6yWzCvWYGB0j6Jacblz0)

# %%
# answer here
# Out:
# Gender  Geography
# Female  France       2261
#         Germany      1193
#         Spain        1089
# Male    France       2753
#         Spain        1388
#         Germany      1316
# Name: Geography, dtype: int64

# %% [markdown]
# ## Question 3
#
# Does credit score vary by age? Create a scatterplot that plots age against credit score to better understand. Do you see anything? Can you think of a quick and easy way to get a better view of what's happening?

# %%
#answer here

# %% [markdown]
# # Part 2 (Bonus)
#
# Let's play a bit with salaries of ``Data_Scientists``. The following dataset contains information about the Data Scientists from 2017 until 2020:

# %%
#let's extract the three columns we care about, and drop NaN values, reset the index, and rename the column label
ds = pd.read_csv("/content/drive/My Drive/Courses/Applied Data Science in Python/datasets/Data_Scientists.csv", usecols=["Year","Country","ConvertedComp"])

ds = ds.dropna().reset_index(drop=True).rename(columns={"ConvertedComp":"Salary"})
ds.head()
# Out:
#    Year         Country    Salary
# 0  2020   United States  116000.0
# 1  2020  United Kingdom   32315.0
# 2  2020  United Kingdom   40070.0
# 3  2020           Spain   14268.0
# 4  2020     Netherlands   38916.0

# %% [markdown]
# ## Question 4
#
# Plot the average annual salaries of data scientists in the US, UK, Canada and Germany from 2017 until 2020.
#
# Just for fun, increase the marker size of all 4 lines and give every line a different line style and marker.
#
# Don't forget to add a legend.

# %%
#answer here
